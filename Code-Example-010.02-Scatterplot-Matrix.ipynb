# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Correlation
#
# Is there an association between the number of hours spent studying and the performance on the final exam?

# %%
ceo_df = pd.read_csv("./datasets/CEO_salary.csv")
ceo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     100 non-null    int64
#  1   height  100 non-null    int64
#  2   salary  100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %%
ceo_df
# Out:
#     age  height  salary
# 0    57      74  518889
# 1    64      74  536408
# 2    52      70  496345
# 3    63      64  508838
# 4    29      75  451312
# ..  ...     ...     ...
# 95   60      67  508847
# 96   60      72  521384
# 97   35      64  438752
# 98   27      70  433771
# 99   47      78  503887
#
# [100 rows x 3 columns]

# %%
age = ceo_df["age"]
salary = ceo_df["salary"]

# %%
fig = plt.figure()
plt.scatter(age, salary, c="red", alpha=0.9, marker='*',label="salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend(loc='upper left')
plt.show()

# %%
fig.savefig('Correlation-CEO.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
# Or save it as PDF file
fig.savefig('Correlation-CEO.pdf')
plt.show()

# %%
# See Pandas Documentation for pandas correlation calculation. 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html?highlight=corr
ceo_df.corr()
# Out:
#              age    height    salary
# age     1.000000 -0.062864  0.929197
# height -0.062864  1.000000  0.310440
# salary  0.929197  0.310440  1.000000

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(ceo_df, alpha = 1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d851ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8536b80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d85e2df0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d861a280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d86466d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8672a60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8672b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d86ac040>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8703850>]],
#       dtype=object)

# %%
scatter_matrix(ceo_df, alpha = 1, diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d87e8b80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8811490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8849be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d88fe370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8928af0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d895e1f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d895e2e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d8985ac0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd6d89e6970>]],
#       dtype=object)

# %%
# Install seaborn
#! pip install seaborn

# %%
import seaborn as sns

sns.pairplot(ceo_df)
